# %% [markdown]
# # Этап 6 V2 — проверка вычислительной реализуемости TabM
#
# ## Исследовательский вопрос
#
# Может ли облегчённая конфигурация TabM завершить обучение на KOMUS за разумное время и дать первичную оценку качества?
#
# ## Зачем сейчас нужна проверка реализуемости
#
# Этап 6 V1 с `k=32`, тремя внешними фолдами и лимитом 1000 эпох не завершился за восемь часов и не дал метрик. Поэтому до повторного полного запуска требуется отдельный короткий диагностический прогон: он отвечает на вопрос о скорости и завершении обучения, а не о превосходстве над GBDT.
#
# ## Что проверяем
#
# Запускается только первый фолд заранее зафиксированного `StratifiedKFold`. У TabM уменьшено только `k` до 8 и ограничено число эпох до 100; подбор и поиск параметров отсутствуют. Прогон ограничен двумя часами, чтобы диагностическая проверка не стала неконтролируемой вычислительной задачей.
#
# ## Что остаётся неизменным
#
# Используются `Data_final.xlsb`, целевой признак `DefMark`, идентификатор `INN`, те же 47 разрешённых признаков в том же порядке, исключение `Q_B1_norm` и `Q_B2_norm`, проверка SHA-256, предобработка без заполнения пропусков, фиксированное разбиение 80/20 с зерном случайности 42 и зерном 43 для первого фолда. Закрытая 20%-выборка создаётся только как часть воспроизводимого разбиения и немедленно освобождается: она не участвует ни в обучении, ни в прогнозе, ни в метриках.
#
# Этот блокнот не заменяет Этап 6 V1, не выполняет финальное сравнение моделей и не сохраняет новые отчётные артефакты.

# %% [markdown]
# ## Подготовка контракта эксперимента
#
# 1. **Что проверяем?** Доступность данных, точную идентичность 47 признаков и параметры облегчённого запуска.
# 2. **Зачем это делаем сейчас?** Диагностика имеет смысл только при сохранении исходного исследовательского контракта.
# 3. **Как этот код отвечает на исследовательский вопрос?** Он загружает список признаков из принятого базового результата Этапа 1 и задаёт единственную облегчающую конфигурацию.
# 4. **Что остаётся неизменным?** Данные, целевой признак, исключённые признаки, порядок признаков и зерна случайности.

# %%
from __future__ import annotations

import hashlib
import json
import random
import time
from pathlib import Path

import numpy as np
import pandas as pd
import tabm
import torch
import torch.nn.functional as F
from sklearn.metrics import average_precision_score, f1_score, precision_score, recall_score, roc_auc_score
from sklearn.model_selection import StratifiedKFold, train_test_split
from torch.utils.data import DataLoader, TensorDataset


def project_root() -> Path:
    current = Path.cwd().resolve()
    for candidate in (current, *current.parents):
        if (candidate / 'pyproject.toml').exists():
            return candidate
    raise FileNotFoundError('Не найден корень проекта с pyproject.toml.')


def sha256_file(path: Path) -> str:
    digest = hashlib.sha256()
    with path.open('rb') as handle:
        for block in iter(lambda: handle.read(1024 * 1024), b''):
            digest.update(block)
    return digest.hexdigest()


def hash_indices(values: np.ndarray) -> str:
    return hashlib.sha256(np.asarray(values, dtype=np.int64).tobytes()).hexdigest()


def set_fold_seed(seed: int) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.use_deterministic_algorithms(True)


ROOT = project_root()
DATASET = ROOT / 'data' / 'raw' / 'Data_final.xlsb'
BASELINE_PATH = ROOT / 'reports' / 'generated' / 'stage1_baseline_results_V2.json'
EXPECTED_DATASET_SHA256 = 'fc742be66d238c529daba52ccc755f774f836b7d052ed062cdf0b345080e7930'
EXPECTED_WORKING_INDEX_SHA256 = '80430ce6290d0982d3641621ba1ed62f6fb495e8d32f7d23d9fca00091aadb45'
TARGET = 'DefMark'
IDENTIFIER = 'INN'
FORBIDDEN_FEATURES = ['Q_B1_norm', 'Q_B2_norm']
OUTER_SEED = 42
OUTER_FOLD_NUMBER = 1
FOLD_SEED = 43
MAX_EPOCHS = 100
PATIENCE = 16
RUNTIME_BUDGET_SECONDS = 2 * 60 * 60
PROGRESS_EVERY_BATCHES = 10
TABM_CONFIG = {
    'arch_type': 'tabm', 'k': 8, 'n_blocks': 3, 'd_block': 512,
    'activation': 'ReLU', 'dropout': 0.10, 'start_scaling_init': 'random-signs',
    'num_embeddings': None, 'd_out': 2, 'input_dtype': 'float32',
    'optimizer': 'AdamW', 'lr': 0.002, 'weight_decay': 0.0003,
    'betas': (0.9, 0.999), 'eps': 1e-8, 'gradient_clip_global_norm': 1.0,
    'batch_size': 256, 'share_training_batches': True, 'max_epochs': MAX_EPOCHS,
    'amp': False, 'torch_compile': False, 'scheduler': None, 'warmup': None,
    'class_weights': None, 'sampling': None,
}

with BASELINE_PATH.open(encoding='utf-8') as handle:
    baseline = json.load(handle)
FEATURES = baseline['допустимые_признаки']
if len(FEATURES) != 47 or any(name in FEATURES for name in FORBIDDEN_FEATURES):
    raise ValueError('Нарушен контракт Stage 1: требуется ровно 47 разрешённых признаков.')

print({'этап': 'конфигурация', 'признаков': len(FEATURES), 'k': TABM_CONFIG['k'], 'максимум_эпох': MAX_EPOCHS, 'внешний_фолд': OUTER_FOLD_NUMBER, 'seed_фолда': FOLD_SEED})
# Out:
# {'этап': 'конфигурация', 'признаков': 47, 'k': 8, 'максимум_эпох': 100, 'внешний_фолд': 1, 'seed_фолда': 43}

# %% [markdown]
# ## Обучение с наблюдаемым прогрессом
#
# 1. **Что проверяем?** Способно ли обучение с `k=8` продвигаться по эпохам и завершить отбор эпохи и дообучение.
# 2. **Зачем это делаем сейчас?** Именно отсутствие наблюдаемого завершения стало ограничением V1.
# 3. **Как этот код отвечает на исследовательский вопрос?** До и после долгих операций, каждые 10 батчей и после каждой эпохи выводятся этап, фолд, число эпох, минуты, лучший ROC-AUC и оценка оставшегося времени.
# 4. **Что остаётся неизменным?** Архитектурные параметры, кроме `k`, оптимизатор, размер батча, ранняя остановка, способ выбора эпохи и последующее дообучение соответствуют V1.

# %%
class RuntimeBudgetExceeded(RuntimeError):
    pass


def elapsed_seconds(started_at: float) -> float:
    return time.perf_counter() - started_at


def check_budget(started_at: float) -> None:
    if elapsed_seconds(started_at) > RUNTIME_BUDGET_SECONDS:
        raise RuntimeBudgetExceeded('Превышен двухчасовой лимит диагностического запуска.')


def show_progress(stage: str, epoch: int | None, total_epochs: int | None, started_at: float, best_auc: float | None, batch: int | None = None, batches: int | None = None, estimated_remaining_seconds: float | None = None) -> None:
    message = {
        'этап': stage, 'фолд': OUTER_FOLD_NUMBER,
        'текущая_эпоха': epoch, 'максимум_эпох': total_epochs,
        'эпоха': None if epoch is None or total_epochs is None else f'{epoch}/{total_epochs}',
        'прошло_минут': round(elapsed_seconds(started_at) / 60.0, 2),
        'лучший_ROC_AUC': None if best_auc is None or not np.isfinite(best_auc) else round(best_auc, 6),
        'примерно_осталось_минут': None if estimated_remaining_seconds is None else round(max(0.0, estimated_remaining_seconds) / 60.0, 2),
    }
    if batch is not None and batches is not None:
        message['батч'] = f'{batch}/{batches}'
    print(message, flush=True)


def show_stage(stage: str, started_at: float, best_auc: float | None = None) -> None:
    show_progress(stage, None, MAX_EPOCHS, started_at, best_auc)


def make_model(n_features: int) -> tabm.TabM:
    return tabm.TabM.make(
        n_num_features=n_features, cat_cardinalities=None,
        arch_type=TABM_CONFIG['arch_type'], k=TABM_CONFIG['k'],
        n_blocks=TABM_CONFIG['n_blocks'], d_block=TABM_CONFIG['d_block'],
        activation=TABM_CONFIG['activation'], dropout=TABM_CONFIG['dropout'],
        start_scaling_init=TABM_CONFIG['start_scaling_init'],
        num_embeddings=None, d_out=TABM_CONFIG['d_out'],
    )


def make_loader(x: np.ndarray, y: np.ndarray, seed: int, shuffle: bool) -> DataLoader:
    generator = torch.Generator(device='cpu').manual_seed(seed)
    dataset = TensorDataset(torch.from_numpy(x), torch.from_numpy(y.astype(np.int64)))
    return DataLoader(dataset, batch_size=TABM_CONFIG['batch_size'], shuffle=shuffle, generator=generator, num_workers=0, drop_last=False)


def fit_one_epoch(model: tabm.TabM, loader: DataLoader, optimizer: torch.optim.Optimizer, started_at: float, stage: str, epoch: int, total_epochs: int, best_auc: float | None) -> None:
    model.train()
    batches = len(loader)
    epoch_started_at = time.perf_counter()
    for batch_number, (x_batch, y_batch) in enumerate(loader, start=1):
        check_budget(started_at)
        optimizer.zero_grad(set_to_none=True)
        logits = model(x_batch.float())
        targets = y_batch[:, None].expand(-1, model.k).reshape(-1)
        loss = F.cross_entropy(logits.reshape(-1, 2), targets)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), TABM_CONFIG['gradient_clip_global_norm'])
        optimizer.step()
        if batch_number == 1 or batch_number % PROGRESS_EVERY_BATCHES == 0 or batch_number == batches:
            batch_seconds = (time.perf_counter() - epoch_started_at) / batch_number
            remaining_batches = (batches - batch_number) + max(0, total_epochs - epoch) * batches
            show_progress(stage, epoch, total_epochs, started_at, best_auc, batch_number, batches, batch_seconds * remaining_batches)


@torch.inference_mode()
def positive_probabilities(model: tabm.TabM, x: np.ndarray, started_at: float, stage: str, epoch: int, total_epochs: int, best_auc: float | None) -> np.ndarray:
    model.eval()
    tensor = torch.from_numpy(x).float()
    chunks: list[np.ndarray] = []
    starts = list(range(0, len(tensor), TABM_CONFIG['batch_size']))
    prediction_started_at = time.perf_counter()
    for chunk_number, start in enumerate(starts, start=1):
        check_budget(started_at)
        logits = model(tensor[start:start + TABM_CONFIG['batch_size']])
        chunks.append(torch.softmax(logits, dim=-1).mean(dim=1)[:, 1].cpu().numpy())
        if chunk_number == 1 or chunk_number % PROGRESS_EVERY_BATCHES == 0 or chunk_number == len(starts):
            chunk_seconds = (time.perf_counter() - prediction_started_at) / chunk_number
            show_progress(stage, epoch, total_epochs, started_at, best_auc, chunk_number, len(starts), chunk_seconds * (len(starts) - chunk_number))
    return np.concatenate(chunks)


def make_optimizer(model: tabm.TabM) -> torch.optim.Optimizer:
    return torch.optim.AdamW(model.parameters(), lr=TABM_CONFIG['lr'], weight_decay=TABM_CONFIG['weight_decay'], betas=TABM_CONFIG['betas'], eps=TABM_CONFIG['eps'])


def select_best_epoch(x_outer: np.ndarray, y_outer: np.ndarray, started_at: float) -> tuple[int, float]:
    show_stage('выбор эпохи: подготовка', started_at)
    fit_idx, inner_idx = train_test_split(np.arange(len(y_outer)), test_size=0.10, stratify=y_outer, random_state=FOLD_SEED)
    set_fold_seed(FOLD_SEED)
    model = make_model(x_outer.shape[1])
    optimizer = make_optimizer(model)
    loader = make_loader(x_outer[fit_idx], y_outer[fit_idx], FOLD_SEED, shuffle=True)
    best_epoch, best_auc, stale_epochs = 0, float('-inf'), 0
    epoch_durations: list[float] = []
    show_stage('выбор эпохи: модель и данные готовы', started_at)
    for epoch in range(1, MAX_EPOCHS + 1):
        epoch_started_at = time.perf_counter()
        fit_one_epoch(model, loader, optimizer, started_at, 'выбор_эпохи: обучение', epoch, MAX_EPOCHS, best_auc)
        probability = positive_probabilities(model, x_outer[inner_idx], started_at, 'выбор_эпохи: валидация', epoch, MAX_EPOCHS, best_auc)
        auc = float(roc_auc_score(y_outer[inner_idx], probability))
        if auc > best_auc:
            best_epoch, best_auc, stale_epochs = epoch, auc, 0
        else:
            stale_epochs += 1
        progress_state['лучший_внутренний_ROC_AUC'] = best_auc
        executed_epochs['выбор_эпохи'] = epoch
        epoch_durations.append(time.perf_counter() - epoch_started_at)
        eta_seconds = float(np.mean(epoch_durations)) * (MAX_EPOCHS - epoch)
        show_progress('выбор эпохи: итог эпохи', epoch, MAX_EPOCHS, started_at, best_auc, estimated_remaining_seconds=eta_seconds)
        if stale_epochs >= PATIENCE:
            show_progress('ранняя остановка', epoch, MAX_EPOCHS, started_at, best_auc, estimated_remaining_seconds=0.0)
            break
    del model, optimizer
    show_progress('выбор эпохи: завершён', executed_epochs['выбор_эпохи'], MAX_EPOCHS, started_at, best_auc, estimated_remaining_seconds=0.0)
    return best_epoch, best_auc


def refit_and_predict(x_train: np.ndarray, y_train: np.ndarray, x_valid: np.ndarray, best_epoch: int, best_auc: float, started_at: float) -> np.ndarray:
    show_progress('дообучение внешнего фолда: подготовка', 0, best_epoch, started_at, best_auc)
    set_fold_seed(FOLD_SEED)
    model = make_model(x_train.shape[1])
    optimizer = make_optimizer(model)
    loader = make_loader(x_train, y_train, FOLD_SEED, shuffle=True)
    show_progress('дообучение внешнего фолда: модель и данные готовы', 0, best_epoch, started_at, best_auc)
    for epoch in range(1, best_epoch + 1):
        fit_one_epoch(model, loader, optimizer, started_at, 'дообучение внешнего фолда', epoch, best_epoch, best_auc)
        executed_epochs['дообучение'] = epoch
        show_progress('дообучение внешнего фолда: итог эпохи', epoch, best_epoch, started_at, best_auc)
    show_progress('прогноз внешней валидации: начало', best_epoch, best_epoch, started_at, best_auc)
    probability = positive_probabilities(model, x_valid, started_at, 'прогноз внешней валидации', best_epoch, best_epoch, best_auc)
    del model, optimizer
    show_progress('прогноз внешней валидации: завершён', best_epoch, best_epoch, started_at, best_auc, estimated_remaining_seconds=0.0)
    return probability


def metrics(y_true: np.ndarray, probability: np.ndarray) -> dict[str, float]:
    predicted = (probability >= 0.5).astype(np.int64)
    auc = float(roc_auc_score(y_true, probability))
    return {
        'ROC-AUC': auc, 'Gini': 2.0 * auc - 1.0, 'PR-AUC': float(average_precision_score(y_true, probability)),
        'Precision@0.5': float(precision_score(y_true, predicted, zero_division=0)),
        'Recall@0.5': float(recall_score(y_true, predicted, zero_division=0)),
        'F1@0.5': float(f1_score(y_true, predicted, zero_division=0)),
    }

# %% [markdown]
# ## Контролируемый диагностический запуск
#
# 1. **Что проверяем?** Фактическое время одного полного внешнего фолда и наличие первичных метрик.
# 2. **Зачем это делаем сейчас?** Это минимально достаточная нагрузка для решения, оправдан ли повторный полный запуск.
# 3. **Как этот код отвечает на исследовательский вопрос?** Он проверяет SHA-256, воспроизводит рабочую выборку, берёт только фолд №1, обучает TabM, рассчитывает метрики на его внешней валидации и печатает понятный итог.
# 4. **Что остаётся неизменным?** Закрытая часть разбиения не используется; нет подбора гиперпараметров, обучения GBDT или записи результатов в файловую систему.

# %%
started_at = time.perf_counter()
run_status = 'не запущен'
fold_metrics: dict[str, float] | None = None
best_epoch: int | None = None
best_inner_auc: float | None = None
executed_epochs = {'выбор_эпохи': 0, 'дообучение': 0}
progress_state = {'лучший_внутренний_ROC_AUC': None}

try:
    show_stage('проверка SHA-256 данных: начало', started_at)
    if sha256_file(DATASET) != EXPECTED_DATASET_SHA256:
        raise ValueError('SHA-256 набора данных не совпадает с зафиксированным контрактом.')
    show_stage('проверка SHA-256 данных: завершена', started_at)

    show_stage('загрузка данных: начало', started_at)
    data = pd.read_excel(DATASET, engine='pyxlsb')
    show_stage('загрузка данных: завершена', started_at)
    show_stage('проверка схемы и подготовка предикторов: начало', started_at)
    allowed_columns = [column for column in data.columns if column not in [TARGET, IDENTIFIER, *FORBIDDEN_FEATURES]]
    if allowed_columns != FEATURES:
        raise ValueError('Идентичность или порядок разрешённых признаков отличаются от Stage 1.')
    if any(name in FEATURES or name in allowed_columns for name in FORBIDDEN_FEATURES):
        raise ValueError('Запрещённые признаки обнаружены среди предикторов.')

    x_all = data.loc[:, FEATURES].to_numpy(dtype=np.float32)
    y_all = data[TARGET].to_numpy(dtype=np.int64)
    if x_all.shape[1] != 47 or not np.isfinite(x_all).all():
        raise ValueError('Нарушено число признаков либо обнаружены NaN/non-finite значения; imputation не выполняется.')
    show_stage('проверка схемы и подготовка предикторов: завершена', started_at)

    show_stage('воспроизведение рабочего разбиения: начало', started_at)
    all_indices = np.arange(len(data))
    working_indices, holdout_indices = train_test_split(all_indices, test_size=0.20, stratify=y_all, random_state=OUTER_SEED)
    if len(working_indices) != 289614 or len(holdout_indices) != 72404:
        raise ValueError('Размер зафиксированного разбиения не совпадает с контрактом.')
    if hash_indices(working_indices) != EXPECTED_WORKING_INDEX_SHA256:
        raise ValueError('SHA рабочих индексов не совпадает с контрактом Stage 1.')
    x_work, y_work = x_all[working_indices], y_all[working_indices]
    del data, x_all, y_all, all_indices, holdout_indices
    show_stage('воспроизведение рабочего разбиения: завершено', started_at)

    outer_cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=OUTER_SEED)
    train_idx, valid_idx = next(outer_cv.split(x_work, y_work))
    show_stage('первый внешний фолд: индексы готовы', started_at)
    print({'этап': 'первый внешний фолд: размеры', 'фолд': OUTER_FOLD_NUMBER, 'строк_обучения': len(train_idx), 'строк_валидации': len(valid_idx), 'прошло_минут': round(elapsed_seconds(started_at) / 60.0, 2)}, flush=True)

    best_epoch, best_inner_auc = select_best_epoch(x_work[train_idx], y_work[train_idx], started_at)
    probability = refit_and_predict(x_work[train_idx], y_work[train_idx], x_work[valid_idx], best_epoch, best_inner_auc, started_at)
    show_progress('расчёт метрик первого фолда: начало', best_epoch, best_epoch, started_at, best_inner_auc)
    fold_metrics = metrics(y_work[valid_idx], probability)
    show_progress('расчёт метрик первого фолда: завершён', best_epoch, best_epoch, started_at, best_inner_auc, estimated_remaining_seconds=0.0)
    run_status = 'завершён'

except RuntimeBudgetExceeded:
    run_status = 'превышен двухчасовой лимит'
    show_progress('превышен двухчасовой лимит', None, MAX_EPOCHS, started_at, progress_state['лучший_внутренний_ROC_AUC'], estimated_remaining_seconds=None)

except Exception as error:
    run_status = f'ошибка: {type(error).__name__}'
    print({'этап': 'ошибка', 'фолд': OUTER_FOLD_NUMBER, 'описание': str(error), 'прошло_минут': round(elapsed_seconds(started_at) / 60.0, 2)}, flush=True)

runtime_seconds = elapsed_seconds(started_at)
observed_best_inner_auc = best_inner_auc if best_inner_auc is not None else progress_state['лучший_внутренний_ROC_AUC']
recommend_full_v2 = run_status == 'завершён' and runtime_seconds <= RUNTIME_BUDGET_SECONDS
result_summary = {
    'обучение_завершилось': run_status == 'завершён',
    'статус': run_status,
    'время_минут': round(runtime_seconds / 60.0, 2),
    'эпох_выбора_выполнено': executed_epochs['выбор_эпохи'],
    'эпох_дообучения_выполнено': executed_epochs['дообучение'],
    'всего_эпох_выполнено': sum(executed_epochs.values()),
    'метрики_получены': fold_metrics is not None,
    'метрики_первого_фолда': fold_metrics,
    'лучшая_эпоха': best_epoch,
    'лучший_внутренний_ROC_AUC': observed_best_inner_auc,
    'рекомендация': 'можно переходить к полному эксперименту' if recommend_full_v2 else 'нужно изменить вычислительный план',
}
print('\nИТОГ ПРОВЕРКИ')
print(json.dumps(result_summary, ensure_ascii=False, indent=2))
# Out:
# {'этап': 'проверка SHA-256 данных: начало', 'фолд': 1, 'текущая_эпоха': None, 'максимум_эпох': 100, 'эпоха': None, 'прошло_минут': 0.0, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': None}
# {'этап': 'проверка SHA-256 данных: завершена', 'фолд': 1, 'текущая_эпоха': None, 'максимум_эпох': 100, 'эпоха': None, 'прошло_минут': 0.0, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': None}
# {'этап': 'загрузка данных: начало', 'фолд': 1, 'текущая_эпоха': None, 'максимум_эпох': 100, 'эпоха': None, 'прошло_минут': 0.0, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': None}
# {'этап': 'загрузка данных: завершена', 'фолд': 1, 'текущая_эпоха': None, 'максимум_эпох': 100, 'эпоха': None, 'прошло_минут': 1.9, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': None}
# {'этап': 'проверка схемы и подготовка предикторов: начало', 'фолд': 1, 'текущая_эпоха': None, 'максимум_эпох': 100, 'эпоха': None, 'прошло_минут': 1.9, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': None}
# {'этап': 'проверка схемы и подготовка предикторов: завершена', 'фолд': 1, 'текущая_эпоха': None, 'максимум_эпох': 100, 'эпоха': None, 'прошло_минут': 1.91, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': None}
# {'этап': 'воспроизведение рабочего разбиения: начало', 'фолд': 1, 'текущая_эпоха': None, 'максимум_эпох': 100, 'эпоха': None, 'прошло_минут': 1.91, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': None}
# {'этап': 'воспроизведение рабочего разбиения: завершено', 'фолд': 1, 'текущая_эпоха': None, 'максимум_эпох': 100, 'эпоха': None, 'прошло_минут': 1.92, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': None}
# {'этап': 'первый внешний фолд: индексы готовы', 'фолд': 1, 'текущая_эпоха': None, 'максимум_эпох': 100, 'эпоха': None, 'прошло_минут': 1.92, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': None}
# {'этап': 'первый внешний фолд: размеры', 'фолд': 1, 'строк_обучения': 193076, 'строк_валидации': 96538, 'прошло_минут': 1.92}
# {'этап': 'выбор эпохи: подготовка', 'фолд': 1, 'текущая_эпоха': None, 'максимум_эпох': 100, 'эпоха': None, 'прошло_минут': 1.92, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': None}
# {'этап': 'выбор эпохи: модель и данные готовы', 'фолд': 1, 'текущая_эпоха': None, 'максимум_эпох': 100, 'эпоха': None, 'прошло_минут': 1.97, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': None}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 1.98, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 148.85, 'батч': '1/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 1.99, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 140.01, 'батч': '10/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.01, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 136.17, 'батч': '20/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.03, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 136.29, 'батч': '30/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.06, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 138.44, 'батч': '40/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.08, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 139.72, 'батч': '50/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.1, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 139.58, 'батч': '60/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.12, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 143.86, 'батч': '70/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.16, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 154.32, 'батч': '80/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.18, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 157.88, 'батч': '90/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.21, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 160.32, 'батч': '100/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.23, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 159.0, 'батч': '110/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.25, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 156.83, 'батч': '120/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.27, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 155.05, 'батч': '130/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.29, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 153.36, 'батч': '140/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.31, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 151.64, 'батч': '150/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.33, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 150.82, 'батч': '160/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.35, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 150.52, 'батч': '170/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.38, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 151.94, 'батч': '180/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.4, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 152.62, 'батч': '190/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.43, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 153.3, 'батч': '200/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.45, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 153.18, 'батч': '210/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.47, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 152.67, 'батч': '220/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.49, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 152.2, 'батч': '230/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.52, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 152.96, 'батч': '240/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.54, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 153.84, 'батч': '250/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.57, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 155.44, 'батч': '260/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.6, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 155.71, 'батч': '270/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.62, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 156.17, 'батч': '280/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.64, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 156.3, 'батч': '290/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.67, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 156.4, 'батч': '300/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.69, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 156.85, 'батч': '310/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.72, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 157.73, 'батч': '320/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.75, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 158.1, 'батч': '330/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.77, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 158.69, 'батч': '340/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.8, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 158.93, 'батч': '350/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.82, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 159.07, 'батч': '360/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.84, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 159.01, 'батч': '370/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.87, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 158.94, 'батч': '380/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.89, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 159.11, 'батч': '390/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.92, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 159.25, 'батч': '400/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.94, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 159.29, 'батч': '410/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.97, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 159.33, 'батч': '420/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 2.99, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 159.39, 'батч': '430/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.02, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 159.86, 'батч': '440/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.05, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 160.92, 'батч': '450/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.07, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 161.16, 'батч': '460/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.1, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 161.67, 'батч': '470/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.13, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 161.81, 'батч': '480/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.15, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 161.24, 'батч': '490/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.18, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 161.96, 'батч': '500/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.2, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 161.72, 'батч': '510/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.22, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 161.69, 'батч': '520/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.25, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 162.62, 'батч': '530/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.28, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 163.35, 'батч': '540/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.31, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 163.1, 'батч': '550/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.33, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 162.87, 'батч': '560/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.35, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 162.85, 'батч': '570/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.38, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 163.03, 'батч': '580/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.41, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 163.68, 'батч': '590/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.43, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 163.69, 'батч': '600/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.46, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 163.68, 'батч': '610/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.48, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 163.5, 'батч': '620/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.5, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 163.48, 'батч': '630/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.53, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 163.4, 'батч': '640/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.56, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 163.87, 'батч': '650/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.59, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 164.91, 'батч': '660/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.62, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 164.82, 'батч': '670/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.64, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 164.78, 'батч': '679/679'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.64, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 0.05, 'батч': '1/76'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.65, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 0.05, 'батч': '10/76'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.65, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 0.03, 'батч': '20/76'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.66, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 0.03, 'батч': '30/76'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.66, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 0.02, 'батч': '40/76'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.67, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 0.01, 'батч': '50/76'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.67, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 0.01, 'батч': '60/76'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.67, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 0.0, 'батч': '70/76'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.68, 'лучший_ROC_AUC': None, 'примерно_осталось_минут': 0.0, 'батч': '76/76'}
# {'этап': 'выбор эпохи: итог эпохи', 'фолд': 1, 'текущая_эпоха': 1, 'максимум_эпох': 100, 'эпоха': '1/100', 'прошло_минут': 3.68, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 168.69}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 3.68, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 169.31, 'батч': '1/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 3.7, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 169.91, 'батч': '10/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 3.73, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 177.41, 'батч': '20/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 3.75, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 170.45, 'батч': '30/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 3.78, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 168.95, 'батч': '40/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 3.8, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 167.68, 'батч': '50/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 3.83, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 165.27, 'батч': '60/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 3.85, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 163.68, 'батч': '70/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 3.87, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 162.35, 'батч': '80/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 3.9, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 162.23, 'батч': '90/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 3.92, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 161.27, 'батч': '100/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 3.95, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 165.07, 'батч': '110/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 3.98, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 170.2, 'батч': '120/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.02, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 176.02, 'батч': '130/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.05, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 178.65, 'батч': '140/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.08, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 180.37, 'батч': '150/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.11, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 180.77, 'батч': '160/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.13, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 179.61, 'батч': '170/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.16, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 177.87, 'батч': '180/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.18, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 176.24, 'батч': '190/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.2, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 175.98, 'батч': '200/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.23, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 174.99, 'батч': '210/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.25, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 173.61, 'батч': '220/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.27, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 172.56, 'батч': '230/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.29, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 171.69, 'батч': '240/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.32, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 171.55, 'батч': '250/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.34, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 170.85, 'батч': '260/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.37, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 170.73, 'батч': '270/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.39, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 170.89, 'батч': '280/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.42, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 170.76, 'батч': '290/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.44, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 169.83, 'батч': '300/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.46, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 169.48, 'батч': '310/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.49, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 168.97, 'батч': '320/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.51, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 168.14, 'батч': '330/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.53, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 167.39, 'батч': '340/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.55, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 166.65, 'батч': '350/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.57, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 165.78, 'батч': '360/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.59, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 164.98, 'батч': '370/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.61, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 164.75, 'батч': '380/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.64, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 165.0, 'батч': '390/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.67, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 165.37, 'батч': '400/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.69, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 165.17, 'батч': '410/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.72, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 165.33, 'батч': '420/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.74, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 164.87, 'батч': '430/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.76, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 164.34, 'батч': '440/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.78, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 163.63, 'батч': '450/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.8, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 163.59, 'батч': '460/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.83, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 163.24, 'батч': '470/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.85, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 163.51, 'батч': '480/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.88, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 163.19, 'батч': '490/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.9, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 163.08, 'батч': '500/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.93, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 163.47, 'батч': '510/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.96, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 164.21, 'батч': '520/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 4.99, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 164.52, 'батч': '530/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.01, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 164.16, 'батч': '540/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.03, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 164.32, 'батч': '550/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.06, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 164.04, 'батч': '560/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.08, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 164.14, 'батч': '570/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.11, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 164.29, 'батч': '580/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.13, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 164.03, 'батч': '590/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.15, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 163.68, 'батч': '600/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.17, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 163.43, 'батч': '610/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.2, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 163.46, 'батч': '620/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.22, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 163.42, 'батч': '630/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.25, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 163.34, 'батч': '640/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.27, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 163.55, 'батч': '650/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.3, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 163.66, 'батч': '660/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.33, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 163.81, 'батч': '670/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.35, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 163.85, 'батч': '679/679'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.35, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 0.04, 'батч': '1/76'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.35, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 0.03, 'батч': '10/76'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.36, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 0.03, 'батч': '20/76'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.36, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 0.02, 'батч': '30/76'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.37, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 0.02, 'батч': '40/76'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.37, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 0.01, 'батч': '50/76'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.38, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 0.01, 'батч': '60/76'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.38, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 0.0, 'батч': '70/76'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.39, 'лучший_ROC_AUC': 0.879423, 'примерно_осталось_минут': 0.0, 'батч': '76/76'}
# {'этап': 'выбор эпохи: итог эпохи', 'фолд': 1, 'текущая_эпоха': 2, 'максимум_эпох': 100, 'эпоха': '2/100', 'прошло_минут': 5.39, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 167.28}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 5.39, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 180.22, 'батч': '1/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 5.41, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 166.16, 'батч': '10/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 5.44, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 160.92, 'батч': '20/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 5.46, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 171.36, 'батч': '30/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 5.49, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 174.62, 'батч': '40/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 5.52, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 181.07, 'батч': '50/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 5.55, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 176.33, 'батч': '60/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 5.57, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 172.11, 'батч': '70/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 5.59, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 168.78, 'батч': '80/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 5.62, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 172.59, 'батч': '90/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 5.65, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 174.86, 'батч': '100/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 5.69, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 180.71, 'батч': '110/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 5.72, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 181.25, 'батч': '120/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 5.74, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 180.03, 'батч': '130/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 5.77, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 179.37, 'батч': '140/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 5.79, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 177.83, 'батч': '150/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 5.81, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 176.02, 'батч': '160/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 5.84, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 174.93, 'батч': '170/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 5.86, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 173.15, 'батч': '180/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 5.88, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 171.25, 'батч': '190/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 5.91, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 172.28, 'батч': '200/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 5.94, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 173.73, 'батч': '210/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 5.96, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 173.13, 'батч': '220/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 5.99, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 172.71, 'батч': '230/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.01, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 171.77, 'батч': '240/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.03, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 171.11, 'батч': '250/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.06, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 171.05, 'батч': '260/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.08, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 170.19, 'батч': '270/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.11, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 170.49, 'батч': '280/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.13, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 170.15, 'батч': '290/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.16, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 170.3, 'батч': '300/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.19, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 170.99, 'батч': '310/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.21, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 171.06, 'батч': '320/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.24, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 171.03, 'батч': '330/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.27, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 171.35, 'батч': '340/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.29, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 171.41, 'батч': '350/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.32, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 171.5, 'батч': '360/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.35, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 171.45, 'батч': '370/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.37, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 170.95, 'батч': '380/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.39, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 170.83, 'батч': '390/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.43, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 171.75, 'батч': '400/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.45, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 171.34, 'батч': '410/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.47, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 170.78, 'батч': '420/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.5, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 171.01, 'батч': '430/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.53, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 171.44, 'батч': '440/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.55, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 171.18, 'батч': '450/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.58, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 170.74, 'батч': '460/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.6, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 170.69, 'батч': '470/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.63, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 170.51, 'батч': '480/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.65, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 170.32, 'батч': '490/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.68, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 170.23, 'батч': '500/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.7, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 170.43, 'батч': '510/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.73, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 170.63, 'батч': '520/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.76, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 170.85, 'батч': '530/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.78, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 170.31, 'батч': '540/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.8, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 169.64, 'батч': '550/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.82, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 168.84, 'батч': '560/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.84, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 168.51, 'батч': '570/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.87, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 168.28, 'батч': '580/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.89, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 167.98, 'батч': '590/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.91, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 167.79, 'батч': '600/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 6.94, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 167.5, 'батч': '610/679'}
# ...
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 7.12, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 168.13, 'батч': '679/679'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 7.12, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 0.04, 'батч': '1/76'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 7.13, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 0.04, 'батч': '10/76'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 7.13, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 0.03, 'батч': '20/76'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 7.14, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 0.03, 'батч': '30/76'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 7.14, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 0.02, 'батч': '40/76'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 7.15, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 0.01, 'батч': '50/76'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 7.15, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 0.01, 'батч': '60/76'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 7.16, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 0.0, 'батч': '70/76'}
# {'этап': 'выбор_эпохи: валидация', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 7.16, 'лучший_ROC_AUC': 0.882909, 'примерно_осталось_минут': 0.0, 'батч': '76/76'}
# {'этап': 'выбор эпохи: итог эпохи', 'фолд': 1, 'текущая_эпоха': 3, 'максимум_эпох': 100, 'эпоха': '3/100', 'прошло_минут': 7.16, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 167.82}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.17, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 216.56, 'батч': '1/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.19, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 177.15, 'батч': '10/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.21, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 166.26, 'батч': '20/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.24, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 158.71, 'батч': '30/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.26, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 156.43, 'батч': '40/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.28, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 155.38, 'батч': '50/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.31, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 155.3, 'батч': '60/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.33, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 154.31, 'батч': '70/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.35, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 154.33, 'батч': '80/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.37, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 152.93, 'батч': '90/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.39, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 151.72, 'батч': '100/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.42, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 150.89, 'батч': '110/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.44, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 150.91, 'батч': '120/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.46, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 151.59, 'батч': '130/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.49, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 152.03, 'батч': '140/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.51, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 151.31, 'батч': '150/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.53, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 151.47, 'батч': '160/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.55, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 150.52, 'батч': '170/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.57, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 149.7, 'батч': '180/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.6, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 149.58, 'батч': '190/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.62, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 150.59, 'батч': '200/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.65, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 150.49, 'батч': '210/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.67, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 150.48, 'батч': '220/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.69, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 149.64, 'батч': '230/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.71, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 149.3, 'батч': '240/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.73, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 148.96, 'батч': '250/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.75, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 148.63, 'батч': '260/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.78, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 148.5, 'батч': '270/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.8, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 148.7, 'батч': '280/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.82, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 148.04, 'батч': '290/679'}
# {'этап': 'выбор_эпохи: обучение', 'фолд': 1, 'текущая_эпоха': 4, 'максимум_эпох': 100, 'эпоха': '4/100', 'прошло_минут': 7.84, 'лучший_ROC_AUC': 0.884929, 'примерно_осталось_минут': 147.37, 'батч': '300/679'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 58
#      54 except RuntimeBudgetExceeded:
#      55     run_status = 'превышен двухчасовой лимит'
#      56     show_progress('превышен двухчасовой лимит', None, MAX_EPOCHS, started_at, progress_state['лучший_внутренний_ROC_AUC'], estimated_remaining_seconds=None)
#      57
# ---> 58 except Exception as error:
#      59     run_status = f'ошибка: {type(error).__name__}'
#      60     print({'этап': 'ошибка', 'фолд': OUTER_FOLD_NUMBER, 'описание': str(error), 'прошло_минут': round(elapsed_seconds(started_at) / 60.0, 2)}, flush=True)
#      61
#
# Cell In[2], line 101, in select_best_epoch(x_outer, y_outer, started_at)
#      97     epoch_durations: list[float] = []
#      98     show_stage('выбор эпохи: модель и данные готовы', started_at)
#      99     for epoch in range(1, MAX_EPOCHS + 1):
#     100         epoch_started_at = time.perf_counter()
# --> 101         fit_one_epoch(model, loader, optimizer, started_at, 'выбор_эпохи: обучение', epoch, MAX_EPOCHS, best_auc)
#     102         probability = positive_probabilities(model, x_outer[inner_idx], started_at, 'выбор_эпохи: валидация', epoch, MAX_EPOCHS, best_auc)
#     103         auc = float(roc_auc_score(y_outer[inner_idx], probability))
#     104         if auc > best_auc:
#
# Cell In[2], line 56, in fit_one_epoch(model, loader, optimizer, started_at, stage, epoch, total_epochs, best_auc)
#      52     epoch_started_at = time.perf_counter()
#      53     for batch_number, (x_batch, y_batch) in enumerate(loader, start=1):
#      54         check_budget(started_at)
#      55         optimizer.zero_grad(set_to_none=True)
# ---> 56         logits = model(x_batch.float())
#      57         targets = y_batch[:, None].expand(-1, model.k).reshape(-1)
#      58         loss = F.cross_entropy(logits.reshape(-1, 2), targets)
#      59         loss.backward()
#
# File d:\Projects\komus-credit-risk\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File d:\Projects\komus-credit-risk\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File d:\Projects\komus-credit-risk\.venv\Lib\site-packages\tabm.py:1803, in TabM.forward(self, x_num, x_cat)
#    1800     x = x.unflatten(0, (batch_size, self.backbone.k))  # (B * K, D) -> (B, K, D)
#    1802 x = self.ensemble_view(x)
# -> 1803 x = self.backbone(x)
#    1804 if self.output is not None:
#    1805     x = self.output(x)
#
# File d:\Projects\komus-credit-risk\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File d:\Projects\komus-credit-risk\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File d:\Projects\komus-credit-risk\.venv\Lib\site-packages\tabm.py:1422, in MLPBackboneBatchEnsemble.forward(self, x)
#    1420 _check_input_min_ndim(x, 'x', 3)
#    1421 for block in self.blocks:
# -> 1422     x = block(x)
#    1423 return x
#
# File d:\Projects\komus-credit-risk\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File d:\Projects\komus-credit-risk\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File d:\Projects\komus-credit-risk\.venv\Lib\site-packages\torch\nn\modules\container.py:253, in Sequential.forward(self, input)
#     249 """
#     250 Runs the forward pass.
#     251 """
#     252 for module in self:
# --> 253     input = module(input)
#     254 return input
#
# File d:\Projects\komus-credit-risk\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File d:\Projects\komus-credit-risk\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File d:\Projects\komus-credit-risk\.venv\Lib\site-packages\torch\nn\modules\dropout.py:73, in Dropout.forward(self, input)
#      69 def forward(self, input: Tensor) -> Tensor:
#      70     """
#      71     Runs the forward pass.
#      72     """
# ---> 73     return F.dropout(input, self.p, self.training, self.inplace)
#
# File d:\Projects\komus-credit-risk\.venv\Lib\site-packages\torch\nn\functional.py:1491, in dropout(input, p, training, inplace)
#    1488 if p < 0.0 or p > 1.0:
#    1489     raise ValueError(f"dropout probability has to be between 0 and 1, but got {p}")
#    1490 return (
# -> 1491     _VF.dropout_(input, p, training) if inplace else _VF.dropout(input, p, training)
#    1492 )
#
# KeyboardInterrupt:

# %% [markdown]
# ## ФАКТЫ
#
# В блоке «ИТОГ ПРОВЕРКИ» выше явно выводятся: завершилось ли обучение, время в минутах, число выполненных эпох выбора и дообучения, их сумма, лучшая эпоха, лучший внутренний ROC-AUC, наличие метрик и рекомендация. До выполнения здесь нет предзаполненного результата.
#
# ## ИНТЕРПРЕТАЦИЯ
#
# Если статус «завершён» и метрики получены, облегчённая конфигурация технически выполнима в пределах диагностического лимита. Это основание только для планирования следующего запуска с пересмотром ожидаемого времени; это не доказательство качества TabM относительно базового результата. Если лимит превышен или произошла ошибка, полный запуск в текущем виде не рекомендуется.
#
# ## ОГРАНИЧЕНИЯ
#
# Один фолд не оценивает вариативность по фолдам и не даёт статистической значимости. Случайная CV не доказывает временную стабильность. Метрики при пороге 0.5 являются только диагностическими. Проверка не сравнивает TabM с GBDT и не использует закрытую часть данных.
#
# ## СЛЕДУЩИЙ ШАГ
#
# При успешном завершении зафиксировать фактическую скорость, оценить масштабирование на три фолда и отдельно утвердить вычислительный бюджет перед полным Этапом 6 V2. При неуспехе сначала уменьшить вычислительную нагрузку или изменить среду выполнения, затем повторить проверку вычислительной реализуемости.
